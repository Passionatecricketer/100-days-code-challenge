# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
import tensorflow

# %%
import librosa

# %%
import IPython.display as ipd
ipd.Audio('data/trimmed.wav')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
data, sampling_rate = librosa.load('data/trimmed.wav')

# %%
% pylab inline
import os
import pandas as pd
import librosa.display
import glob 

plt.figure(figsize=(12, 4))
librosa.display.waveplot(data, sr=sampling_rate)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
i = random.choice(train.index)

audio_name = train.ID[i]
path = os.path.join(data_dir, 'data', str(audio_name) + '.wav')

print('Class: ', train.Class[i])
x, sr = librosa.load('data/' + str(train.ID[i]) + '.wav')

plt.figure(figsize=(12, 4))
librosa.display.waveplot(x, sr=sr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-1d738359fa48> in <module>()
# ----> 1 i = random.choice(train.index)
#       2
#       3 audio_name = train.ID[i]
#       4 path = os.path.join(data_dir, 'data', str(audio_name) + '.wav')
#       5
#
# NameError: name 'train' is not defined
